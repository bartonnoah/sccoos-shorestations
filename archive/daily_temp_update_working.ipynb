# %%
import pandas as pd
import numpy as np
import sys

import datetime
from datetime import date, time
from datetime import datetime

# Matplotlib Library
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
filename='SIO_TEMP_20230105.csv'
pd.read_csv(filename, usecols = ['SURF_TEMP_C','MONTH','DAY'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 filename='SIO_TEMP_20230105.csv'
# ----> 2 pd.read_csv(filename, usecols = ['SURF_TEMP_C','MONTH','DAY'])
#
# File ~/Library/CloudStorage/OneDrive-UCSanDiego/SCCOOS/SCCOOS-shorestations/n_obs/env/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-UCSanDiego/SCCOOS/SCCOOS-shorestations/n_obs/env/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
def daily_temp_update(filename, station):
    #setting up working dataframe
    all_sst = pd.read_csv(filename, usecols = ['SURF_TEMP_C','MONTH','DAY'])
    today = datetime.now()
    day = today.day
    month = today.month
    today_sst = all_sst['SURF_TEMP_C'].iloc[-1]
    climatology = all_sst[(all_sst['MONTH'] == month) & (all_sst['DAY'] == day)]
# Out:
# /var/folders/69/cbrnkm0j709dqnkmhv8wnwgw0000gp/T/ipykernel_35192/3063388188.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row1['index1'] = row1.index
# /var/folders/69/cbrnkm0j709dqnkmhv8wnwgw0000gp/T/ipykernel_35192/3063388188.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row2['index1'] = row2.index

# %%
fig, ax = plt.subplots(figsize=(12, 6), dpi=200)

x = np.arange(0, 10, 0.1)
y = 1

ax.plot(y, color='blue', label='Sine wave')

plt.xlim([0, 50])
plt.ylim([0, 20])

plt.axis('off')

plt.annotate("Temperature", fontsize = 100, c='white', xy=(.25,.9), xycoords="axes fraction") 
plt.annotate("{}˚C".format(SIO_TEMP_C_SURF), fontsize = 120, fontweight='bold', c='steelblue', xy=(.25,.8), xycoords="axes fraction") 
plt.annotate("  {}˚F".format(SIO_TEMP_F_SURF), fontsize = 80, fontweight='bold', c='skyblue', xy=(.27,.55), xycoords="axes fraction") 
plt.annotate("Measured on:", fontsize = 30, style='italic', c='grey', xy=(.25,.4), xycoords="axes fraction") 
plt.annotate("{}".format(SIO_DATE), fontsize = 45, weight='bold',  c='black', xy=(.25,.25), xycoords="axes fraction") 
plt.annotate("at {}".format(SIO_TIME), fontsize = 35, weight='bold',  c='dimgrey', xy=(.25,.1), xycoords="axes fraction") 

plt.savefig('/Volumes/sccoos/manual_shore_station/DATA/TEMPERATURE/AutomatedPlotsForMSSwebsite/SIO_surf_temp_now.png', bbox_inches='tight', dpi=400)
